# %% [markdown]
# ## Problem statement
#
# ### Dataset
#
# The data set we’ll be using is the Iris Flower Dataset which was first introduced in 1936 by the famous statistician Ronald Fisher and consists of 50 observations from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals.
#
# **Attributes of the dataset:** https://archive.ics.uci.edu/ml/datasets/Iris
#
# **Train the KNN algorithm to be able to distinguish the species from one another given the measurements of the 4 features.**

# %% [markdown]
# ## Naive Bayes

# %%
#Load all required library
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB

# %% [markdown]
# ### Import Iris.csv

# %%
Iris_df = pd.read_csv('Iris.csv', header = 0)

# %%
# Check dimension of data

# %%
Iris_df.shape
# Out:
# (152, 6)

# %%
#Check data Type

# %%
Iris_df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
# Check for NaN/Null values
print("Sum of Nan\n:", Iris_df.isna().sum())
print("Sum of Null",Iris_df.isnull().sum())
# Out:
# Sum of Nan
# : Id               0
# SepalLengthCm    1
# SepalWidthCm     2
# PetalLengthCm    2
# PetalWidthCm     1
# Species          0
# dtype: int64
# Sum of Null Id               0
# SepalLengthCm    1
# SepalWidthCm     2
# PetalLengthCm    2
# PetalWidthCm     1
# Species          0
# dtype: int64

# %% [markdown]
# ### Its not good to remove the records having missing values all the time. We may end up loosing some data points. So, we will have to see how to replace those missing values with some estimated values (median)

# %%
Iris_df= Iris_df.replace(np.nan,Iris_df.mean())

# %% [markdown]
# ### Slice data set for Independent variables and dependent variables ( 1 Marks)
# #### Please note 'Species' is my dependent variables, name it y and independent set data as X

# %%
Y = Iris_df['Species']
X = Iris_df.drop(columns=['Species'])

# %%
#Check the dataset
print(Y)
print(X)
print(Y.shape)
print(X.shape)
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
# 5         Iris-setosa
# 6         Iris-setosa
# 7         Iris-setosa
# 8         Iris-setosa
# 9         Iris-setosa
# 10        Iris-setosa
# 11        Iris-setosa
# 12        Iris-setosa
# 13        Iris-setosa
# 14        Iris-setosa
# 15        Iris-setosa
# 16        Iris-setosa
# 17        Iris-setosa
# 18        Iris-setosa
# 19        Iris-setosa
# 20        Iris-setosa
# 21        Iris-setosa
# 22        Iris-setosa
# 23        Iris-setosa
# 24        Iris-setosa
# 25        Iris-setosa
# 26        Iris-setosa
# 27        Iris-setosa
# 28        Iris-setosa
# 29        Iris-setosa
#             ...
# 122    Iris-virginica
# 123    Iris-virginica
# 124    Iris-virginica
# 125    Iris-virginica
# 126    Iris-virginica
# 127    Iris-virginica
# 128    Iris-virginica
# 129    Iris-virginica
# 130    Iris-virginica
# 131    Iris-virginica
# 132    Iris-virginica
# 133    Iris-virginica
# 134    Iris-virginica
# 135    Iris-virginica
# 136    Iris-virginica
# 137    Iris-virginica
# 138    Iris-virginica
# 139    Iris-virginica
# 140    Iris-virginica
# 141    Iris-virginica
# 142    Iris-virginica
# 143    Iris-virginica
# 144    Iris-virginica
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# 150    Iris-virginica
# 151    Iris-virginica
# Name: Species, Length: 152, dtype: object
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1       5.100000         3.500       1.400000      0.200000
# 1      2       4.900000         3.000       1.400000      0.200000
# 2      3       4.700000         3.200       1.300000      0.200000
# 3      4       4.600000         3.100       1.500000      0.200000
# 4      5       5.000000         3.600       1.400000      0.200000
# 5      6       5.400000         3.900       1.700000      0.400000
# 6      7       4.600000         3.400       1.400000      0.300000
# 7      8       5.000000         3.400       1.500000      0.200000
# 8      9       4.400000         2.900       1.400000      0.200000
# 9     10       4.900000         3.100       1.500000      0.100000
# 10    11       5.400000         3.700       1.500000      0.200000
# 11    12       4.800000         3.400       1.600000      0.200000
# 12    13       4.800000         3.000       1.400000      0.100000
# 13    14       4.300000         3.000       1.100000      0.100000
# 14    15       5.800000         4.000       1.200000      0.200000
# 15    16       5.700000         4.400       1.500000      0.400000
# 16    17       5.400000         3.900       1.300000      0.400000
# 17    18       5.100000         3.500       1.400000      0.300000
# 18    19       5.700000         3.800       1.700000      0.300000
# 19    20       5.100000         3.800       1.500000      0.300000
# 20    21       5.400000         3.400       1.700000      0.200000
# 21    22       5.100000         3.700       1.500000      0.400000
# 22    23       4.600000         3.600       1.000000      0.200000
# 23    24       5.100000         3.300       1.700000      0.500000
# 24    25       4.800000         3.400       1.900000      0.200000
# 25    26       5.000000         3.000       1.600000      0.200000
# 26    27       5.000000         3.400       1.600000      0.400000
# 27    28       5.200000         3.500       1.500000      0.200000
# 28    29       5.200000         3.400       1.400000      0.200000
# 29    30       4.700000         3.200       1.600000      0.200000
# ..   ...            ...           ...            ...           ...
# 122  123       7.700000         2.800       6.700000      2.000000
# 123  124       6.300000         2.700       4.900000      1.800000
# 124  125       6.700000         3.300       5.700000      2.100000
# 125  126       7.200000         3.200       6.000000      1.800000
# 126  127       6.200000         2.800       4.800000      1.800000
# 127  128       6.100000         3.000       4.900000      1.800000
# 128  129       6.400000         2.800       5.600000      2.100000
# 129  130       7.200000         3.000       5.800000      1.600000
# 130  131       7.400000         2.800       6.100000      1.900000
# 131  132       7.900000         3.800       6.400000      2.000000
# 132  133       6.400000         2.800       5.600000      2.200000
# 133  134       6.300000         2.800       5.100000      1.500000
# 134  135       6.100000         2.600       5.600000      1.400000
# 135  136       7.700000         3.000       6.100000      2.300000
# 136  137       6.300000         3.400       5.600000      2.400000
# 137  138       6.400000         3.100       5.500000      1.800000
# 138  139       6.000000         3.000       4.800000      1.800000
# 139  140       6.900000         3.100       5.400000      2.100000
# 140  141       6.700000         3.100       5.600000      2.400000
# 141  142       6.900000         3.100       5.100000      2.300000
# 142  143       5.800000         2.700       5.100000      1.900000
# 143  144       6.800000         3.200       5.900000      2.300000
# 144  145       6.700000         3.300       5.700000      2.500000
# 145  146       6.700000         3.000       5.200000      2.300000
# 146  147       6.300000         2.500       5.000000      1.900000
# 147  148       6.500000         3.000       5.200000      2.000000
# 148  149       6.200000         3.400       5.400000      2.300000
# 149  150       5.900000         3.000       5.100000      1.800000
# 150  151       5.900000         3.054       3.758667      1.202649
# 151  152       5.843709         3.054       3.758667      1.800000
#
# [152 rows x 5 columns]
# (152,)
# (152, 5)

# %% [markdown]
# ### Find the distribution of target variable (Class) (1 Marks)

# %%
## Target Variable Frequency Distribution
freq = Y.value_counts().to_frame()
freq.reset_index(inplace=True)
freq.columns = [freq.columns[1], 'count']
freq['prop'] = freq['count'] / sum(freq['count'])
freq
# Out:
#            Species  count      prop
# 0   Iris-virginica     52  0.342105
# 1  Iris-versicolor     50  0.328947
# 2      Iris-setosa     50  0.328947

# %% [markdown]
# ### Plot the distribution of target variable using histogram

# %%
import seaborn as sns
sns.countplot(Y)

# %% [markdown]
# ### Plot Scatter Matrix to understand the distribution of variables and give insights from it( 1 Marks)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(Iris_df, alpha=0.2,diagonal='kde',figsize=(15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3CA3EE80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3CBA9438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3CBC5CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3CBEB7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3D4F0240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3D4F0278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3D532780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3D557240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3D576CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3D59B780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3D5BF240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3D5E0CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3D604780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3D629240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3D647CC0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3D66B780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3D692240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3D6AFCC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3D6D3780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3D6FA240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3D719CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3D73C780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3D761240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3D782CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3D7A5780>]],
#       dtype=object)

# %% [markdown]
# ### Summary Statistics and explain insights for at least 2 variables (1 Marks)

# %%
Iris_df.describe(include='all').transpose()
# Out:
#               count unique             top freq     mean       std  min  \
# Id              152    NaN             NaN  NaN     76.5   44.0227    1
# SepalLengthCm   152    NaN             NaN  NaN  5.84371  0.822577  4.3
# SepalWidthCm    152    NaN             NaN  NaN    3.054  0.430713    2
# PetalLengthCm   152    NaN             NaN  NaN  3.75867    1.7527    1
# PetalWidthCm    152    NaN             NaN  NaN  1.20265  0.759657  0.1
# Species         152      3  Iris-virginica   52      NaN       NaN  NaN
#
#                  25%   50%     75%  max
# Id             38.75  76.5  114.25  152
# SepalLengthCm    5.1   5.8     6.4  7.9
# SepalWidthCm     2.8     3     3.3  4.4
# PetalLengthCm    1.6   4.3     5.1  6.9
# PetalWidthCm     0.3   1.3     1.8  2.5
# Species          NaN   NaN     NaN  NaN

# %% [markdown]
# From Above Summary, we can see that
# 1. Standard deviation of Sepal length is 0.82, standard deviation of Petal width is 1.76
# 2. Target variable Species does not have any missing values whereas others have.
# 3. Target variable has 3 categaries.

# %%
#Drop Id variable from data

X = X.drop(columns='Id')

# %% [markdown]
# ### Correlation among all variables and give your insights (1 Marks)

# %%
#Please note, it's Require to remove correlated features because they are voted twice in the model and 
## it can lead to over inflating importance.We will ignore it here
corr = X.corr()
corr
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109368       0.871741      0.816256
# SepalWidthCm       -0.109368      1.000000      -0.420516     -0.355808
# PetalLengthCm       0.871741     -0.420516       1.000000      0.960771
# PetalWidthCm        0.816256     -0.355808       0.960771      1.000000

# %% [markdown]
# We can see that every variable has a high correlation so will not drop any variable here.

# %% [markdown]
# ### Split data in Training and Validation in 80:20 (1 Marks)

# %%
### SPLITTING INTO TRAINING AND TEST SETS
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20,random_state = 100)

# %% [markdown]
# ### Do Feature Scaling ( 1 Marks)

# %%
# Use StandardScaler or similar methods
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()
print(scaler.fit(X_train))
print(scaler.mean_)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)
# [5.84380165 3.03515702 3.79717906 1.2215095 ]

# %% [markdown]
# ### Train and Fit NaiveBayes Model(2 Marks)

# %%
#Fit the model

# %%
clf = GaussianNB()
GNB = clf.fit(X_train, y_train)
print(GNB)
# Out:
# GaussianNB(priors=None)

# %%
#Predict
from sklearn import metrics
y_predict = GNB.predict(X_test)
print(y_predict)
print(GNB.score(X_train,y_train))
print(GNB.score(X_test,y_predict))
# Out:
# ['Iris-virginica' 'Iris-setosa' 'Iris-versicolor' 'Iris-setosa'
#  'Iris-virginica' 'Iris-virginica' 'Iris-setosa' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-setosa' 'Iris-virginica'
#  'Iris-setosa' 'Iris-setosa' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-setosa' 'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-virginica' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-virginica' 'Iris-versicolor']
# 0.9504132231404959
# 1.0

# %% [markdown]
# ### Print Accuracy and Confusion Matrix and Conclude your findings(1 Marks)

# %%
# show Confusion Matrix

# %%
conf_mat = metrics.confusion_matrix(y_test, y_predict)
print(conf_mat)
# Out:
# [[12  0  0]
#  [ 0  7  0]
#  [ 0  3  9]]

# %%
# show accuracy

# %%
GNB.score(X_train,y_train)
# Out:
# 0.9504132231404959

# %%
#Show precision and Recall metrics

# %%
from sklearn.metrics import precision_recall_fscore_support
precision_recall_fscore_support(y_test, y_predict, average='macro')
# Out:
# (0.9, 0.9166666666666666, 0.8935574229691876, None)

# %%
true_pos = np.diag(conf_mat) 
precision = np.sum(true_pos / np.sum(conf_mat, axis=0))
recall = np.sum(true_pos / np.sum(conf_mat, axis=1))

print(recall)
print(precision)
# Out:
# 2.75
# 2.7

# %% [markdown]
# ## K-Nearest-Neighbors

# %% [markdown]
# # Reload your Iris.Csv and repeat it for KNN using following steps

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
from sklearn.neighbors import KNeighborsClassifier
from scipy.stats import zscore
from sklearn.preprocessing import Imputer
from sklearn.metrics import accuracy_score
import seaborn as sns
import os

# %% [markdown]
# KNN falls in the supervised learning family of algorithms. Informally, this means that we are given a labelled dataset consiting of training observations (x,y) and would like to capture the relationship between x and y. More formally, our goal is to learn a function h:X→Y so that given an unseen observation x, h(x) can confidently predict the corresponding output y.
#
# In this module we will explore the inner workings of KNN, choosing the optimal K values and using KNN from scikit-learn.

# %% [markdown]
# ## Question 1 - Import Iris.csv

# %%
Iris_knn_df = pd.read_csv('Iris.csv', header = 0)

# %% [markdown]
# ## Question 2 - Estimating missing values
#
# *Its not good to remove the records having missing values all the time. We may end up loosing some data points. So, we will have to see how to replace those missing values with some estimated values (median) *

# %%
Iris_knn_df.fillna(Iris_knn_df.median(), inplace = True)
Iris_knn_df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5           1.40           0.2
# 1      2            4.9           3.0           1.40           0.2
# 2      3            4.7           3.2           1.30           0.2
# 3      4            4.6           3.1           1.50           0.2
# 4      5            5.0           3.6           1.40           0.2
# 5      6            5.4           3.9           1.70           0.4
# 6      7            4.6           3.4           1.40           0.3
# 7      8            5.0           3.4           1.50           0.2
# 8      9            4.4           2.9           1.40           0.2
# 9     10            4.9           3.1           1.50           0.1
# 10    11            5.4           3.7           1.50           0.2
# 11    12            4.8           3.4           1.60           0.2
# 12    13            4.8           3.0           1.40           0.1
# 13    14            4.3           3.0           1.10           0.1
# 14    15            5.8           4.0           1.20           0.2
# 15    16            5.7           4.4           1.50           0.4
# 16    17            5.4           3.9           1.30           0.4
# 17    18            5.1           3.5           1.40           0.3
# 18    19            5.7           3.8           1.70           0.3
# 19    20            5.1           3.8           1.50           0.3
# 20    21            5.4           3.4           1.70           0.2
# 21    22            5.1           3.7           1.50           0.4
# 22    23            4.6           3.6           1.00           0.2
# 23    24            5.1           3.3           1.70           0.5
# 24    25            4.8           3.4           1.90           0.2
# 25    26            5.0           3.0           1.60           0.2
# 26    27            5.0           3.4           1.60           0.4
# 27    28            5.2           3.5           1.50           0.2
# 28    29            5.2           3.4           1.40           0.2
# 29    30            4.7           3.2           1.60           0.2
# ..   ...            ...           ...            ...           ...
# 122  123            7.7           2.8           6.70           2.0
# 123  124            6.3           2.7           4.90           1.8
# 124  125            6.7           3.3           5.70           2.1
# 125  126            7.2           3.2           6.00           1.8
# 126  127            6.2           2.8           4.80           1.8
# 127  128            6.1           3.0           4.90           1.8
# 128  129            6.4           2.8           5.60           2.1
# 129  130            7.2           3.0           5.80           1.6
# 130  131            7.4           2.8           6.10           1.9
# 131  132            7.9           3.8           6.40           2.0
# 132  133            6.4           2.8           5.60           2.2
# 133  134            6.3           2.8           5.10           1.5
# 134  135            6.1           2.6           5.60           1.4
# 135  136            7.7           3.0           6.10           2.3
# 136  137            6.3           3.4           5.60           2.4
# 137  138            6.4           3.1           5.50           1.8
# 138  139            6.0           3.0           4.80           1.8
# 139  140            6.9           3.1           5.40           2.1
# 140  141            6.7           3.1           5.60           2.4
# 141  142            6.9           3.1           5.10           2.3
# 142  143            5.8           2.7           5.10           1.9
# 143  144            6.8           3.2           5.90           2.3
# 144  145            6.7           3.3           5.70           2.5
# 145  146            6.7           3.0           5.20           2.3
# 146  147            6.3           2.5           5.00           1.9
# 147  148            6.5           3.0           5.20           2.0
# 148  149            6.2           3.4           5.40           2.3
# 149  150            5.9           3.0           5.10           1.8
# 150  151            5.9           3.0           4.35           1.3
# 151  152            5.8           3.0           4.35           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# 6       Iris-setosa
# 7       Iris-setosa
# 8       Iris-setosa
# 9       Iris-setosa
# 10      Iris-setosa
# 11      Iris-setosa
# 12      Iris-setosa
# 13      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# 16      Iris-setosa
# 17      Iris-setosa
# 18      Iris-setosa
# 19      Iris-setosa
# 20      Iris-setosa
# 21      Iris-setosa
# 22      Iris-setosa
# 23      Iris-setosa
# 24      Iris-setosa
# 25      Iris-setosa
# 26      Iris-setosa
# 27      Iris-setosa
# 28      Iris-setosa
# 29      Iris-setosa
# ..              ...
# 122  Iris-virginica
# 123  Iris-virginica
# 124  Iris-virginica
# 125  Iris-virginica
# 126  Iris-virginica
# 127  Iris-virginica
# 128  Iris-virginica
# 129  Iris-virginica
# 130  Iris-virginica
# 131  Iris-virginica
# 132  Iris-virginica
# 133  Iris-virginica
# 134  Iris-virginica
# 135  Iris-virginica
# 136  Iris-virginica
# 137  Iris-virginica
# 138  Iris-virginica
# 139  Iris-virginica
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
# 150  Iris-virginica
# 151  Iris-virginica
#
# [152 rows x 6 columns]

# %% [markdown]
# ## Question 3 - Dealing with categorical data
#
# Change all the classes to numericals (0to2).

# %%
Iris_knn_df_new = Iris_knn_df

Iris_cat = {"Species": {"Iris-setosa" : 0, "Iris-versicolor" : 1, "Iris-virginica": 2}}

Iris_knn_df_new.replace(Iris_cat, inplace = True)
Iris_knn_df_new.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
print(Iris_knn_df_new)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5           1.40           0.2        0
# 1      2            4.9           3.0           1.40           0.2        0
# 2      3            4.7           3.2           1.30           0.2        0
# 3      4            4.6           3.1           1.50           0.2        0
# 4      5            5.0           3.6           1.40           0.2        0
# 5      6            5.4           3.9           1.70           0.4        0
# 6      7            4.6           3.4           1.40           0.3        0
# 7      8            5.0           3.4           1.50           0.2        0
# 8      9            4.4           2.9           1.40           0.2        0
# 9     10            4.9           3.1           1.50           0.1        0
# 10    11            5.4           3.7           1.50           0.2        0
# 11    12            4.8           3.4           1.60           0.2        0
# 12    13            4.8           3.0           1.40           0.1        0
# 13    14            4.3           3.0           1.10           0.1        0
# 14    15            5.8           4.0           1.20           0.2        0
# 15    16            5.7           4.4           1.50           0.4        0
# 16    17            5.4           3.9           1.30           0.4        0
# 17    18            5.1           3.5           1.40           0.3        0
# 18    19            5.7           3.8           1.70           0.3        0
# 19    20            5.1           3.8           1.50           0.3        0
# 20    21            5.4           3.4           1.70           0.2        0
# 21    22            5.1           3.7           1.50           0.4        0
# 22    23            4.6           3.6           1.00           0.2        0
# 23    24            5.1           3.3           1.70           0.5        0
# 24    25            4.8           3.4           1.90           0.2        0
# 25    26            5.0           3.0           1.60           0.2        0
# 26    27            5.0           3.4           1.60           0.4        0
# 27    28            5.2           3.5           1.50           0.2        0
# 28    29            5.2           3.4           1.40           0.2        0
# 29    30            4.7           3.2           1.60           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 122  123            7.7           2.8           6.70           2.0        2
# 123  124            6.3           2.7           4.90           1.8        2
# 124  125            6.7           3.3           5.70           2.1        2
# 125  126            7.2           3.2           6.00           1.8        2
# 126  127            6.2           2.8           4.80           1.8        2
# 127  128            6.1           3.0           4.90           1.8        2
# 128  129            6.4           2.8           5.60           2.1        2
# 129  130            7.2           3.0           5.80           1.6        2
# 130  131            7.4           2.8           6.10           1.9        2
# 131  132            7.9           3.8           6.40           2.0        2
# 132  133            6.4           2.8           5.60           2.2        2
# 133  134            6.3           2.8           5.10           1.5        2
# 134  135            6.1           2.6           5.60           1.4        2
# 135  136            7.7           3.0           6.10           2.3        2
# 136  137            6.3           3.4           5.60           2.4        2
# 137  138            6.4           3.1           5.50           1.8        2
# 138  139            6.0           3.0           4.80           1.8        2
# 139  140            6.9           3.1           5.40           2.1        2
# 140  141            6.7           3.1           5.60           2.4        2
# 141  142            6.9           3.1           5.10           2.3        2
# 142  143            5.8           2.7           5.10           1.9        2
# 143  144            6.8           3.2           5.90           2.3        2
# 144  145            6.7           3.3           5.70           2.5        2
# 145  146            6.7           3.0           5.20           2.3        2
# 146  147            6.3           2.5           5.00           1.9        2
# 147  148            6.5           3.0           5.20           2.0        2
# 148  149            6.2           3.4           5.40           2.3        2
# 149  150            5.9           3.0           5.10           1.8        2
# 150  151            5.9           3.0           4.35           1.3        2
# 151  152            5.8           3.0           4.35           1.8        2
#
# [152 rows x 6 columns]

# %% [markdown]
# ## Question 4
#
# *Observe the association of each independent variable with target variable and drop variables from feature set having correlation in range -0.1 to 0.1 with target variable.*

# %%
Iris_knn_df_new.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.702734     -0.392693       0.872346
# SepalLengthCm  0.702734       1.000000     -0.109369       0.871120
# SepalWidthCm  -0.392693      -0.109369      1.000000      -0.420713
# PetalLengthCm  0.872346       0.871120     -0.420713       1.000000
# PetalWidthCm   0.890676       0.815986     -0.356510       0.962043
# Species        0.942753       0.775061     -0.417318       0.944477
#
#                PetalWidthCm   Species
# Id                 0.890676  0.942753
# SepalLengthCm      0.815986  0.775061
# SepalWidthCm      -0.356510 -0.417318
# PetalLengthCm      0.962043  0.944477
# PetalWidthCm       1.000000  0.952513
# Species            0.952513  1.000000

# %%
sns.heatmap(Iris_knn_df_new.corr(),annot=True)

# %% [markdown]
# No Column falls under the -.1 to .1 range. So I am not dropping any column here.

# %% [markdown]
# ## Question 5
#
# *Observe the independent variables variance and drop such variables having no variance or almost zero variance(variance < 0.1). They will be having almost no influence on the classification.*

# %%
Iris_knn_df_new = Iris_knn_df_new.drop(columns='Id')

# %%
Y = Iris_knn_df_new['Species']
X = Iris_knn_df_new.drop(columns='Species')
print(X)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5           1.40           0.2
# 1              4.9           3.0           1.40           0.2
# 2              4.7           3.2           1.30           0.2
# 3              4.6           3.1           1.50           0.2
# 4              5.0           3.6           1.40           0.2
# 5              5.4           3.9           1.70           0.4
# 6              4.6           3.4           1.40           0.3
# 7              5.0           3.4           1.50           0.2
# 8              4.4           2.9           1.40           0.2
# 9              4.9           3.1           1.50           0.1
# 10             5.4           3.7           1.50           0.2
# 11             4.8           3.4           1.60           0.2
# 12             4.8           3.0           1.40           0.1
# 13             4.3           3.0           1.10           0.1
# 14             5.8           4.0           1.20           0.2
# 15             5.7           4.4           1.50           0.4
# 16             5.4           3.9           1.30           0.4
# 17             5.1           3.5           1.40           0.3
# 18             5.7           3.8           1.70           0.3
# 19             5.1           3.8           1.50           0.3
# 20             5.4           3.4           1.70           0.2
# 21             5.1           3.7           1.50           0.4
# 22             4.6           3.6           1.00           0.2
# 23             5.1           3.3           1.70           0.5
# 24             4.8           3.4           1.90           0.2
# 25             5.0           3.0           1.60           0.2
# 26             5.0           3.4           1.60           0.4
# 27             5.2           3.5           1.50           0.2
# 28             5.2           3.4           1.40           0.2
# 29             4.7           3.2           1.60           0.2
# ..             ...           ...            ...           ...
# 122            7.7           2.8           6.70           2.0
# 123            6.3           2.7           4.90           1.8
# 124            6.7           3.3           5.70           2.1
# 125            7.2           3.2           6.00           1.8
# 126            6.2           2.8           4.80           1.8
# 127            6.1           3.0           4.90           1.8
# 128            6.4           2.8           5.60           2.1
# 129            7.2           3.0           5.80           1.6
# 130            7.4           2.8           6.10           1.9
# 131            7.9           3.8           6.40           2.0
# 132            6.4           2.8           5.60           2.2
# 133            6.3           2.8           5.10           1.5
# 134            6.1           2.6           5.60           1.4
# 135            7.7           3.0           6.10           2.3
# 136            6.3           3.4           5.60           2.4
# 137            6.4           3.1           5.50           1.8
# 138            6.0           3.0           4.80           1.8
# 139            6.9           3.1           5.40           2.1
# 140            6.7           3.1           5.60           2.4
# 141            6.9           3.1           5.10           2.3
# 142            5.8           2.7           5.10           1.9
# 143            6.8           3.2           5.90           2.3
# 144            6.7           3.3           5.70           2.5
# 145            6.7           3.0           5.20           2.3
# 146            6.3           2.5           5.00           1.9
# 147            6.5           3.0           5.20           2.0
# 148            6.2           3.4           5.40           2.3
# 149            5.9           3.0           5.10           1.8
# 150            5.9           3.0           4.35           1.3
# 151            5.8           3.0           4.35           1.8
#
# [152 rows x 4 columns]

# %%
Iris_knn_df_new.var()
# Out:
# SepalLengthCm    0.676645
# SepalWidthCm     0.185552
# PetalLengthCm    3.076516
# PetalWidthCm     0.577141
# Species          0.675322
# dtype: float64

# %% [markdown]
# ## Question 6
#
# *Plot the scatter matrix for all the variables.*

# %%
pd.scatter_matrix(Iris_knn_df_new,figsize=(15,15))
plt.show()

# %% [markdown]
# ## Split the dataset into training and test sets
#
# ## Question 7
#
# *Split the dataset into training and test sets with 80-20 ratio.*

# %%
from sklearn import neighbors

# %%
from sklearn.model_selection import train_test_split
X_train_KNN, X_test_KNN, y_train_KNN, y_test_KNN = train_test_split(X, Y, test_size=0.20,random_state = 100)

# %% [markdown]
# ## Question 8 - Model
#
# *Build the model and train and test on training and test sets respectively using **scikit-learn**. Print the Accuracy of the model with different values of **k=3,5,9**.*
#
# **Hint:** For accuracy you can check **accuracy_score()** in scikit-learn

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
i=np.array([3,5,9])
n=0
while n<=len(i)-1:
    k=i[n]
    KNN_model = KNeighborsClassifier(n_neighbors = k, weights = 'uniform', metric = 'euclidean')
    KNN_model.fit(X_train_KNN,y_train_KNN)
    y_pred_train = KNN_model.predict(X_train_KNN)
    y_pred_test=KNN_model.predict(X_test_KNN)
    print('\nAccuracy for train dataset for (K=',k,')=',1-accuracy_score(y_train_KNN,y_pred_train))
    print('Accuracy for test dataset for (K=',k,')=',1-accuracy_score(y_test_KNN,y_pred_test))
    n=n+1
# Out:
# Accuracy for train dataset for (K= 3 )= 0.04958677685950408
# Accuracy for test dataset for (K= 3 )= 0.06451612903225812
#
# Accuracy for train dataset for (K= 5 )= 0.04132231404958675
# Accuracy for test dataset for (K= 5 )= 0.06451612903225812
#
# Accuracy for train dataset for (K= 9 )= 0.04132231404958675
# Accuracy for test dataset for (K= 9 )= 0.06451612903225812

# %% [markdown]
# ## Question 9 - Cross Validation
#
# Run the KNN with no of neighbours to be 1,3,5..19 and *Find the **optimal number of neighbours** from the above list using the Mis classification error

# %% [markdown]
# Hint:
#
# Misclassification error (MSE) = 1 - Test accuracy score. Calculated MSE for each model with neighbours = 1,3,5...19 and find the model with lowest MSE

# %%
j = np.arange(1,19,2)
n=0
MSE=[]
k_val=[]
while n<=len(j)-1:
    k=j[n]
    KNN_model = KNeighborsClassifier(n_neighbors = k, weights = 'uniform', metric = 'euclidean')
    KNN_model.fit(X_train_KNN,y_train_KNN)
    y_pred_train = KNN_model.predict(X_train_KNN)
    MSE.append(1-accuracy_score(y_train_KNN,y_pred_train))
    k_val.append(k)
    dataplot=pd.DataFrame([k_val,MSE]).T
    n=n+1
    dataplot.columns=['k','MSE']

dataplot
# Out:
#       k       MSE
# 0   1.0  0.000000
# 1   3.0  0.049587
# 2   5.0  0.041322
# 3   7.0  0.041322
# 4   9.0  0.041322
# 5  11.0  0.041322
# 6  13.0  0.033058
# 7  15.0  0.041322
# 8  17.0  0.033058

# %% [markdown]
# At k= 13, we have lowest MSE so will take k = 13.

# %% [markdown]
# ## Question 10
#
# *Plot misclassification error vs k (with k value on X-axis) using matplotlib.*

# %%
py=sns.lineplot(x='k', y='MSE',data=dataplot).set_title('misclassification error vs k')
